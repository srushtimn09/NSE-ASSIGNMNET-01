# %%
# Student Record Management System

students = []   # list of dictionaries
FILENAME = "students.txt"


# ---------- File Handling ----------
def load_data():
    try:
        with open(FILENAME, "r") as file:
            for line in file:
                roll, name, marks = line.strip().split(",")
                students.append({
                    "roll": int(roll),
                    "name": name,
                    "marks": int(marks)
                })
    except FileNotFoundError:
        pass


def save_data():
    with open(FILENAME, "w") as file:
        for s in students:
            file.write(f"{s['roll']},{s['name']},{s['marks']}\n")


# ---------- Functions ----------
def add_student():
    try:
        roll = int(input("Enter Roll Number: "))
        name = input("Enter Name: ").strip()
        marks = int(input("Enter Marks: "))

        students.append({"roll": roll, "name": name, "marks": marks})
        print("Student added successfully!")

    except ValueError:
        print("Invalid input! Please enter correct values.")


def view_students():
    if len(students) == 0:
        print("No records found.")
    else:
        for s in students:
            print(s)


def search_student():
    key = input("Enter name to search: ").strip().lower()
    found = False

    for s in students:
        if s.get("name").lower() == key:
            print("Record Found:", s)
            found = True

    if not found:
        print("Student not found.")


def delete_student():
    try:
        roll = int(input("Enter roll number to delete: "))
        for s in students:
            if s.get("roll") == roll:
                students.remove(s)
                print("Student deleted.")
                return
        print("Roll number not found.")
    except ValueError:
        print("Invalid input.")


# ---------- Main Program ----------
load_data()

while True:
    print("\n--- Student Record Management ---")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Delete Student")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_student()
    elif choice == "2":
        view_students()
    elif choice == "3":
        search_student()
    elif choice == "4":
        delete_student()
    elif choice == "5":
        save_data()
        print("Data saved. Exiting program.")
        break
    else:
        print("Invalid choice! Please try again.")
# Out:
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  1
# Enter Roll Number:  01
# Enter Name:  Srushti
# Enter Marks:  85
# Student added successfully!
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  1
# Enter Roll Number:  02
# Enter Name:  Veda
# Enter Marks:  90
# Student added successfully!
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  1
# Enter Roll Number:  03
# Enter Name:  Chai
# Enter Marks:  70
# Student added successfully!
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  1
# Enter Roll Number:  Anu
# Invalid input! Please enter correct values.
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  1
# Enter Roll Number:  04
# Enter Name:  Anu
# Enter Marks:  75
# Student added successfully!
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  2
# {'roll': 1, 'name': 'Srushti', 'marks': 85}
# {'roll': 2, 'name': 'Veda', 'marks': 90}
# {'roll': 3, 'name': 'Chai', 'marks': 70}
# {'roll': 4, 'name': 'Anu', 'marks': 75}
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  3
# Enter name to search:  Srushti
# Record Found: {'roll': 1, 'name': 'Srushti', 'marks': 85}
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
# Enter your choice:  4
# Enter roll number to delete:  04
# Student deleted.
#
# --- Student Record Management ---
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Delete Student
# 5. Exit
